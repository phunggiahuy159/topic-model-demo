# %% [markdown]
# <a href="https://colab.research.google.com/github/phunggiahuy159/topic-model-demo/blob/main/chain_free.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%bash
# cd /content/drive/MyDrive/
# ls
# Out:
# 01-NGUYÊN-HÀM-1.pdf
# 07-Trần-Ngọc-Thắng-Lê-Xuân-Đại-MỘT-SỐ-BÀI-TOÁN-VỀ-DÃY-SỐ-NGUYÊN (1).pdf
# 07-Trần-Ngọc-Thắng-Lê-Xuân-Đại-MỘT-SỐ-BÀI-TOÁN-VỀ-DÃY-SỐ-NGUYÊN.pdf
# 1000000000.docx
# 100 BÀI TẬP BẤT ĐẲNG THỨC ÔN THI..pdf.gdrive
# 10-Đề.docx
# 11.doc
# [1]2 Book-Diophantine Equations A Problem-Based Approach(Titu Andresscu).gdoc
# 1ajDZSgxtaiFflBx0qR9ZfymvgBnU468n
# 1DnIMUSHxFVP4MQzT1I2Rr85fQGGCYkRO.pdf
# 2400-cau-hoi-luyen-thi-duong-len-dinh-Olympia-1.pdf
# 2_Linear_Regression.ipynb
# 2. Thay Vu Tuan Anh. Khoa live T. Ly thuyet Song Co.pdf
# 384550308_711665920463161_913905503607450454_n (1).png
# 384550308_711665920463161_913905503607450454_n.png
# 61dedfa37a3edf50993de5b8cb3f3077b4a000.pdf
# 6C.doc
# 70 Bài toán số học, đại số, hình học và tổ hợp lớp 9.pdf
# 7.4. BDHSG To hop - Roi dac.pdf
# 7.jpg
# 9999999999.docx
# AGEST.pdf
# ancol 1. Ngoc.pdf
# ankhan-online.docx
# Apollonius-circles-and-applications.pdf
# ...

# %%
# !git clone https://github.com/BobXWu/CFDTM.git
# !pip install -r requirements.txt
# !python your_script.py
# Out:
# fatal: destination path 'CFDTM' already exists and is not an empty directory.

# %%
# %cd /content/CFDTM/CFDTM
# !ls  # Check if scripts/ exists
# !ls scripts/  # Check if run.sh is inside
# !bash scripts/run.sh NYT 50
# Out:
# /content/CFDTM/CFDTM
# configs  dynamic_topic_model.py  models  output  runners  scripts  utils
# run.sh
#   0% 0/800 [00:00<?, ?it/s]Epoch: 001
#   0% 1/800 [01:03<14:11:51, 63.97s/it]
